# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# '/Users/vijayasri'

# %%
ls ml
# Out:
# 11th aug.ipynb                     cont_pic.png
# 12th aug_lambda.ipynb              dummy.txt
# 12thaug11.ipynb                    example.ipynb
# 13th aug.ipynb                     exceptional_handling.ipynb
# 14th aug.ipynb                     exe2.ipynb
# 22aug_ml.ipynb                     execrcise.ipynb
# 24thaug.ipynb                      hello.py
# 3rd aug.ipynb                      indexofbook.ipynb
# 4thsep.ipynb                       loop.ipynb
# 6th aug.ipynb                      my_files_ml/
# 6thaug_imp.ipynb                   num_def.csv
# 7th aug.ipynb                      operations.ipynb
# Data types.ipynb                   output.csv
# EasyVisa.csv                       preparation.ipynb
# ML-cls1.ipynb                      session. 4.ipynb
# ML.ipynb                           session1.ipynb
# Untitled.ipynb                     session2 variables.ipynb
# aug23_cat_anlalysy.ipynb           session3print.ipynb
# ...

# %%
ls ml
# Out:
# 11th aug.ipynb              dummy.txt
# 12th aug_lambda.ipynb       example.ipynb
# 12thaug11.ipynb             exceptional_handling.ipynb
# 13th aug.ipynb              exe2.ipynb
# 14th aug.ipynb              execrcise.ipynb
# 22aug_ml.ipynb              hello.py
# 24thaug.ipynb               indexofbook.ipynb
# 3rd aug.ipynb               loop.ipynb
# 4thsep.ipynb                my_files_ml/
# 6th aug.ipynb               num_def.csv
# 6thaug_imp.ipynb            operations.ipynb
# 7th aug.ipynb               output.csv
# Data types.ipynb            preparation.ipynb
# EasyVisa.csv                session. 4.ipynb
# ML-cls1.ipynb               session1.ipynb
# ML.ipynb                    session2 variables.ipynb
# Untitled.ipynb              session3print.ipynb
# aug23_cat_anlalysy.ipynb    string_examples.ipynb
# aug8.ipynb                  test_lAUu6dG.csv
# bank.csv                    wine.csv
# cont_pic.png                works/

# %%
file='/Users/vijayasri/ML/wine.csv'
wine_df=pd.read_csv(file)
wine_df
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %%
typ1=wine_df.corr(numeric_only=True)

# %%
typ1.corr()
# Out:
#                           Wine   Alcohol  Malic.acid       Ash       Acl  \
# Wine                  1.000000 -0.462313    0.848053  0.170108  0.848317
# Alcohol              -0.462313  1.000000   -0.171418  0.137397 -0.636188
# Malic.acid            0.848053 -0.171418    1.000000  0.262723  0.682895
# Ash                   0.170108  0.137397    0.262723  1.000000  0.435207
# Acl                   0.848317 -0.636188    0.682895  0.435207  1.000000
# Mg                   -0.467923  0.545503   -0.344408  0.236908 -0.460500
# Phenols              -0.972756  0.441666   -0.829126 -0.156983 -0.811110
# Flavanoids           -0.984057  0.395024   -0.851360 -0.165711 -0.798735
# Nonflavanoid.phenols  0.894706 -0.451120    0.746228  0.247330  0.790329
# Proanth              -0.890747  0.334560   -0.772048 -0.245384 -0.744535
# Color.int             0.473358  0.505147    0.565494  0.344340  0.179293
# Hue                  -0.885690  0.084058   -0.918361 -0.293256 -0.676509
# ...

# %%
plt.figure(figsize=(10,20))
sns.heatmap(typ1,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# it is very imp to convert categorical to num becoz all ml are in nuerical
# methods
# manul by using map methods
# one hot encoder :pd.get_dummies
# label encide:sikit learn package

# %%
ls ml
# Out:
# 11th aug.ipynb              dummy.txt
# 12th aug_lambda.ipynb       example.ipynb
# 12thaug11.ipynb             exceptional_handling.ipynb
# 13th aug.ipynb              exe2.ipynb
# 14th aug.ipynb              execrcise.ipynb
# 22aug_ml.ipynb              hello.py
# 24thaug.ipynb               indexofbook.ipynb
# 3rd aug.ipynb               loop.ipynb
# 4thsep.ipynb                my_files_ml/
# 6th aug.ipynb               num_def.csv
# 6thaug_imp.ipynb            operations.ipynb
# 7th aug.ipynb               output.csv
# Data types.ipynb            preparation.ipynb
# EasyVisa.csv                session. 4.ipynb
# ML-cls1.ipynb               session1.ipynb
# ML.ipynb                    session2 variables.ipynb
# Untitled.ipynb              session3print.ipynb
# aug23_cat_anlalysy.ipynb    string_examples.ipynb
# aug8.ipynb                  test_lAUu6dG.csv
# bank.csv                    wine.csv
# cont_pic.png                works/

# %%
file='/Users/vijayasri/ML/EasyVisa.csv'
visa_df=pd.read_csv(file)

d1={'Certified':1 , 'Denied':0}
visa_df['case_status'].map(d1)
visa_df['case_status']=visa_df['case_status'].map(d1)
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position  case_status
# 0         592.2029         Hour                  Y            0
# ...

# %%
heatmap used only in seaborn 
num vs num only used in heatmap

# %%
d1={}
labels=visa_df['continent'].unique()
for i in range(len(labels)):
    d1[labels[i]]=i
visa_df['continent']=visa_df['continent'].map(d1)
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          0           High School                  N
# 1         EZYV02          0              Master's                  Y
# 2         EZYV03          0            Bachelor's                  N
# 3         EZYV04          0            Bachelor's                  N
# 4         EZYV05          1              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          0            Bachelor's                  Y
# 25476  EZYV25477          0           High School                  Y
# 25477  EZYV25478          0              Master's                  Y
# 25478  EZYV25479          0              Master's                  Y
# 25479  EZYV25480          0            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...
