# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file='/Users/vijayasri/ML/EasyVisa.csv'
data=pd.read_csv(file)
sns.countplot(data=data,x='continent')
values=data['continent'].value_counts()
ax=values.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.show()

# %%
values=data['continent'].value_counts()
ax=values.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.show()

# %%
pie chart

# %%
file='/Users/vijayasri/ML/EasyVisa.csv'
data=pd.read_csv(file)
keys=data['continent'].value_counts().keys()
values=data['continent'].value_counts().to_list()

plt.pie(x=values,
        labels=keys,
        autopct="%0.2f%%",
       explode=[0.2,0.2,0.2,0.3,0.4,0.5],
       shadow=True,
       startangle=80,
       radius=1)
# Out:
# ([<matplotlib.patches.Wedge at 0x113887080>,
# ...
#  [Text(-1.228342681310556, -0.4256456945286702, 'Asia'),
#   Text(1.253255909611414, -0.34547015069911313, 'Europe'),
#   Text(1.0750929313174373, 0.7308728952637937, 'North America'),
#   Text(0.6250370439330497, 1.252728499600546, 'South America'),
#   Text(0.42866254429162864, 1.4374451026461594, 'Africa'),
#   Text(0.31505662454174244, 1.5686743841002708, 'Oceania')],
#  [Text(-0.7559031884988037, -0.26193581201764315, '66.17%'),
#   Text(0.7712344059147161, -0.2125970158148388, '14.65%'),
#   Text(0.6615956500414998, 0.4497679355469499, '12.92%'),
#   Text(0.40180952824267474, 0.8053254640289224, '3.34%'),
#   Text(0.2857750295277524, 0.9582967350974396, '2.16%'),
#   Text(0.21660142937244792, 1.0784636390689362, '0.75%')])

# %%
file='/Users/vijayasri/ML/EasyVisa.csv'
data=pd.read_csv(file)
data.columns
wage=data['prevailing_wage'].count()
wage_max=round(wage.max(),2)
wage_min=round(wage.min(),2)
wage_mean=round(wage.mean(),2)
wage_median=round(wage.median(),2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 8
#       6 wage_min=round(wage.min(),2)
#       7 wage_mean=round(wage.mean(),2)
# ----> 8 wage_median=round(wage.median(),2)
#
# AttributeError: 'numpy.int64' object has no attribute 'median'
