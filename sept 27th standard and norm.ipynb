# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
file='/Users/vijayasri/ML/EasyVisa.csv'
visa_df=pd.read_csv(file)
val=visa_df['prevailing_wage']
mean_val=np.mean(visa_df['prevailing_wage'])
std1=np.std(visa_df['prevailing_wage'])
num=visa_df['prevailing_wage']-mean_val
out=num/std1
visa_df['prevailing_wage_zscore']=out
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
to find standard deviation std we have to find
#column ===visa_df['prevailing_wage']
#mean===np.mean(visa_df['prevailing_wage'])
#std=np.std(visa_df['prevailing_wage'])
#x-meu==visa_df['prevailing_wage']-np.mean(visa_df['prevailing_wage'])
#out==x-meu/std

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status  \
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
pd.DataFrame(zip(val,out))
# Out:
#                  0         1
# 0         592.2029 -1.398537
# 1       83425.6500  0.169835
# 2      122996.8600  0.919079
# 3       83434.0300  0.169994
# 4      149907.3900  1.428604
# ...            ...       ...
# 25475   77092.5700  0.049924
# 25476  279174.7900  3.876159
# 25477  146298.8500  1.360280
# 25478   86154.7700  0.221509
# 25479   70876.9100 -0.067763
#
# [25480 rows x 2 columns]

# %%
a=visa_df['prevailing_wage'].max()
b=visa_df['prevailing_wage_zscore'].max()
c=visa_df['prevailing_wage'].idxmax()
d=visa_df['prevailing_wage_zscore'].idxmax()
c,d
# Out:
# (21077, 21077)

# %%
visa_df.iloc[['21077']]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 21077  EZYV21078      Asia           High School                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 21077                     N              442         2006
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 21077              Midwest        319210.27         Year                  Y
#
#       case_status  prevailing_wage_zscore
# 21077      Denied                4.634193

# %%
visa_df['prevailing_wage'].idxmin()
visa_df['prevailing_wage_zscore'].idxmin()
visa_df.iloc[[20575]]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 20575  EZYV20576  North America              Master's                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 20575                     N             1552         2004
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 20575            Northeast           2.1367         Hour                  Y
#
#       case_status  prevailing_wage_zscore
# 20575   Certified                -1.40971

# %%
a=visa_df['prevailing_wage'].min()
b=visa_df['prevailing_wage_zscore'].min()
a,b
# Out:
# (np.float64(2.1367), np.float64(-1.4097095626210332))

# %%
plt.subplot(1,2,1)
plt.boxplot(visa_df['prevailing_wage'])
plt.subplot(1,2,2)
plt.boxplot(visa_df['prevailing_wage_zscore'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11d05a720>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x11d05a180>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x11d05baa0>],
#  'medians': [<matplotlib.lines.Line2D at 0x11d059bb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11d059970>],
#  'means': []}

# %%
file='/Users/vijayasri/ML/EasyVisa.csv'
visa_df=pd.read_csv(file)
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
visa_df['prevailing_wage_z']=ss.fit_transform(visa_df[['prevailing_wage']])
visa_df[['prevailing_wage_z','prevailing_wage']]
# Out:
#        prevailing_wage_z  prevailing_wage
# 0              -1.398537         592.2029
# 1               0.169835       83425.6500
# 2               0.919079      122996.8600
# 3               0.169994       83434.0300
# 4               1.428604      149907.3900
# ...                  ...              ...
# 25475           0.049924       77092.5700
# 25476           3.876159      279174.7900
# 25477           1.360280      146298.8500
# 25478           0.221509       86154.7700
# 25479          -0.067763       70876.9100
#
# [25480 rows x 2 columns]

# %%
visa_df['prevailing_wage']
min_a=visa_df['prevailing_wage'].min()
max_a=visa_df['prevailing_wage'].max()
num=visa_df['prevailing_wage']-max_a
den=max_a-min_a
out=num/den
visa_df['prevailing_wage_zmin']=out
visa_df.head()
a=visa_df['prevailing_wage_zmin'].min()
b=visa_df['prevailing_wage'].min()
visa_df['prevailing_wage_zmin'].idxmin()
visa_df.iloc[[20575]]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 20575  EZYV20576  North America              Master's                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 20575                     N             1552         2004
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 20575            Northeast           2.1367         Hour                  Y
#
#       case_status  prevailing_wage_z  prevailing_wage_zmin
# 20575   Certified           -1.40971                  -1.0

# %%
file='/Users/vijayasri/ML/EasyVisa.csv'
visa_df=pd.read_csv(file)
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
visa_df['prevailing_wage_z']=mms.fit_transform(visa_df[['prevailing_wage']])
visa_df[['prevailing_wage_z','prevailing_wage']]
# Out:
#        prevailing_wage_z  prevailing_wage
# 0               0.001849         592.2029
# 1               0.261345       83425.6500
# 2               0.385312      122996.8600
# 3               0.261371       83434.0300
# 4               0.469616      149907.3900
# ...                  ...              ...
# 25475           0.241505       77092.5700
# 25476           0.874579      279174.7900
# 25477           0.458311      146298.8500
# 25478           0.269895       86154.7700
# 25479           0.222033       70876.9100
#
# [25480 rows x 2 columns]

# %%
labeal encoder
standard scalear
min max scalear
