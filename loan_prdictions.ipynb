# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# '/Users/vijayasri'

# %%
test_path='/Users/vijayasri/ML/test_lAUu6dG.csv'
test1=pd.read_csv(test_path)
n1=test1['CoapplicantIncome']
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
test1[['CoapplicantIncome_z']]=mms.fit_transform(test1[['CoapplicantIncome']])
test1[['CoapplicantIncome_z','CoapplicantIncome']]
test11=test1['Credit_History']<2.0
np.where(test11,True,False)
test1['status']=np.where(test11,'yes','No')

# %%
test_path='/Users/vijayasri/ML/test_lAUu6dG.csv'
test1=pd.read_csv(test_path)
n1=test1['CoapplicantIncome']
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
test1[['CoapplicantIncome_z']]=mms.fit_transform(test1[['CoapplicantIncome']])
test1[['CoapplicantIncome_z','CoapplicantIncome']]
test1
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
file='/Users/vijayasri/ML/EasyVisa.csv'
visa_df=pd.read_csv(file)
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
visa_df['prevailing_wage_z']=mms.fit_transform(visa_df[['prevailing_wage']])
visa_df[['prevailing_wage_z','prevailing_wage']]

# %%
file='/Users/vijayasri/ML/test_lAUu6dG.csv'
file_data=pd.read_csv(file)

s11=file_data['Credit_History'].min()
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
test_path='/Users/vijayasri/ML/test_lAUu6dG.csv'
test1=pd.read_csv(test_path)
n1=test1['CoapplicantIncome']


est1t1=test1['Credit_History']<2.0

test1['status']=np.where(test11,'yes','No')
test1
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
ls
# Out:
# 11th aug.ipynb                     heat_map.ipynb
# 12th aug_lambda.ipynb              hello.py
# 12thaug11.ipynb                    histogram.ipynb
# 13th aug.ipynb                     indexofbook.ipynb
# 14th aug.ipynb                     loan_prdictions.ipynb
# 22aug_ml.ipynb                     loop.ipynb
# 24thaug.ipynb                      missing_value_oct3.ipynb
# 25thaug.ipynb                      my_files_ml/
# 26th sept.ipynb                    new.py
# 3rd aug.ipynb                      num_def.csv
# 4thsept_mapping .ipynb             oct5_stat.ipynb
# 6th aug.ipynb                      operations.ipynb
# 6thaug_imp.ipynb                   outliers.ipynb
# 7th aug.ipynb                      output.csv
# Data types.ipynb                   plt_pie.ipynb
# ML-cls1.ipynb                      preparation.ipynb
# ML.ipynb                           sept 25.ipynb
# aug23_cat_anlalysy.ipynb           sept 27th standard and norm.ipynb
# ...

# %%
test_path='/Users/vijayasri/ML/test_lAUu6dG.csv'
test1=pd.read_csv(test_path)
test11=test1['Credit_History'].median()>0
test1['status']=np.where(test11,'accepted','denied')
test1.head()
test1['Credit_History']
test1.bfill(axis=1).head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#   ApplicantIncome CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0            5720                 0      110.0            360.0
# 1            3076              1500      126.0            360.0
# 2            5000              1800      208.0            360.0
# 3            2340              2546      100.0            360.0
# 4            3276                 0       78.0            360.0
#
#   Credit_History Property_Area    status
# 0            1.0         Urban  accepted
# 1            1.0         Urban  accepted
# 2            1.0         Urban  accepted
# ...

# %%
test1
from sklearn.impute import KNNImputer
le=KNNImputer()
test1['Credit_History']=le.fit_transform(test1[['Credit_History']])
test1['Credit_History']
test1.head()[:40]
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area    status
# 0        1.000000         Urban  accepted
# 1        1.000000         Urban  accepted
# ...
