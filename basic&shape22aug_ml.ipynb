# %%
import pandas as pd
file='/Users/vijayasri/ML/EasyVisa.csv'
v1=pd.read_csv(file)
v1.tail()
v1.head()
v1.shape
v1.shape[0]
v1.size
type(v1.columns)
v1.dtypes
v1.info()
v1.isnull()
v1.isna()
v1.isna().sum()

# %%
import pandas as pd
file='/Users/vijayasri/ML/EasyVisa.csv'
v1=pd.read_csv(file)
v1.dtypes
type=dict(v1.dtypes)
for i in type:
    if type[i]=='object':
        print(i,'object')
    else:
        print(i,'')

col=[i for i in type if type[i]=='object']
col1=[i for i in type if type[i]!='object']
# Out:
# case_id object
# continent object
# education_of_employee object
# has_job_experience object
# requires_job_training object
# no_of_employees
# yr_of_estab
# region_of_employment object
# prevailing_wage
# unit_of_wage object
# full_time_position object
# case_status object

# %%
#head returns only top first first data when you didnt enter particular value
#will get only last five values when you dont enter a particular values
#shape
#size
#columns
#dtypes
#info
#selective dtypes
#take
#loc===it can take direct colums and rows names not indexes
#iloc==onlu take numerical values thatbis index

# %%
dir(pd)

# %%
woo=dict(v1.dtypes)
for i in woo:
    if i==0:
        print(i,woo)
    else:
        print(i,woo)

# %%
v1.select_dtypes(include='object').columns
v1.select_dtypes(exclude='object').columns
v1.select_dtypes(include='object')
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %%
import pandas as pd
file='/Users/vijayasri/ML/EasyVisa.csv'
v1=pd.read_csv(file)
v1.dtypes
type=dict(v1.dtypes)
v1.take([100,209,305],axis=0)
v1.take([100,209,305]).take([2,3],axis=1)
v1.iloc[1:20,2:6]#both rows and columns are specified
v1.iloc[:,1:3]#only columns are specified
v1.iloc[14:20,:]#only rows are specified
# Out:
#    case_id continent education_of_employee has_job_experience  \
# 14  EZYV15      Asia              Master's                  Y
# 15  EZYV16      Asia           High School                  Y
# 16  EZYV17    Europe              Master's                  Y
# 17  EZYV18      Asia              Master's                  Y
# 18  EZYV19    Africa              Master's                  Y
# 19  EZYV20      Asia             Doctorate                  N
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 14                     Y            15756         2006                South
# 15                     N             4897         1987                 West
# 16                     N            76638         1991              Midwest
# 17                     N             2747         2001                 West
# 18                     N             4743         2004              Midwest
# ...

# %%
rows=[100,200,300]
colums=[1,2,3]
v1.iloc[rows,colums]
# Out:
#     continent education_of_employee has_job_experience
# 100      Asia              Master's                  Y
# 200      Asia             Doctorate                  Y
# 300      Asia              Master's                  Y

# %%
v1.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object
